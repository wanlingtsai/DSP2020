# %%
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot
import numpy as np
import math

import warnings
warnings.filterwarnings('ignore')

from IPython.html.widgets import interact, interact_manual, fixed
from IPython.html import widgets
from IPython.display import display

PI2 = 2 * math.pi

# %% [markdown]
# ## Exercise
# Write a function that takes a Spectrum as a parameter and modifies it by dividing each element of hs by the corresponding frequency from fs. Test your function using one of the WAV files in the repository or any Wave object.編寫一個函數，將頻譜作為參數，並通過將hs的每個元素除以fs的相應頻率來對其進行修改。使用存儲庫中的WAV文件之一或任何Wave對象測試您的功能。
# Compute the Spectrum and plot it.
# Modify the Spectrum using your function and plot it again.
# Make a Wave from the modified Spectrum and listen to it. What effect does this operation have on the signal?對光譜進行操作並繪製。
# 使用您的函數修改頻譜並再次繪製。
# 從修改後的頻譜中發出波浪並聆聽。此操作對信號有什麼影響？
# ## Solution:
# Here's my version of the function:這是我的函數版本：

# %%
def filter_spectrum(spectrum):
    spectrum.hs /= spectrum.fs
    spectrum.hs[0] = 0

# %% [markdown]
# Here's a triangle wave:這是三角波：

# %%
wave = thinkdsp.TriangleSignal(freq=440).make_wave(duration=0.5)
wave.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Here's what the before and after look like. I scaled the after picture to make it visible on the same scale.這是前後的樣子。我按比例縮放後的圖片，使其以相同的比例可見。

# %%
high = 10000
spectrum = wave.make_spectrum()
spectrum.plot(high=high, color='gray')
filter_spectrum(spectrum)
spectrum.scale(440)
spectrum.plot(high=high)

# %% [markdown]
# The filter clobbers the harmonics, so it acts like a low pass filter.
#
# Here's what it sounds like:

# %%
filtered = spectrum.make_wave()
filtered.make_audio()
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The triangle wave now sounds almost like a sine wave.現在，三角波聽起來幾乎像是正弦波。
